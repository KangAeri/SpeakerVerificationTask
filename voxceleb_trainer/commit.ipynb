# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/test
# Out:
# /content/drive/MyDrive/test

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/test/.git/

# %%
# !git config --list
# Out:
# filter.lfs.required=true
# filter.lfs.clean=git-lfs clean -- %f
# filter.lfs.smudge=git-lfs smudge -- %f
# filter.lfs.process=git-lfs filter-process
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://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@github.com/KangAeri/speaker_verification.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*

# %%
# !git config --global user.email "rkddofl12355@gmail.com"

# %%
# !git config --global user.name "KangAeri"

# %%
# !git add .

# %%
# !git commit -m "sv"
# Out:
# [master 58345bf] sv
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite voxceleb_trainer/commit.ipynb (88%)

# %%
# !git remote set-url origin "https://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@github.com/KangAeri/speakerverify.git"

# %%
# !git remote set-url origin "https://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@github.com/KangAeri/speakerverify.git"

# %%
# !git push origin master
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
