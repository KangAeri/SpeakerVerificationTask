# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd drive/MyDrive/test

# %%
# !git init

# %%
# !git config --global user.email "elel235711@gmail.com"

# %%
# !git config --global user.name "KangAeri"

# %%
# !git add .

# %%
# !git commit -m "sv"

# %%
# !git remote set-url origin "https://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@github.com/KangAeri/speaker_verification.git"

# %%
# !git push origin master
